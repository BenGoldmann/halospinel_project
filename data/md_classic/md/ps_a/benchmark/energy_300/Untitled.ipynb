# %%
import glob
import numpy as np
import matplotlib.pyplot as plt

files = glob.glob('*.txt')
files.sort()

for f in files:
    data = np.loadtxt(f, delimiter=' ')
    energy = []
    time = []
    for dat in data[0::500]:
        time.append(dat[0])
        energy.append(dat[1])
    plt.plot(time, energy)
    
plt.xlim(0, 16)
plt.xlabel('time (ns)', size=12)
plt.ylabel('Energy (eV/atom)', size=12)
plt.legend(['3x3x3', '4x4x4', '7x7x7', '8x8x8', '9x9x9'], fontsize=12)

def make_square_axes(ax):
    """Make an axes square in screen units.

    Should be called after plotting.
    """
    ax.set_aspect(1 / ax.get_data_ratio())

make_square_axes(plt.gca())

plt.savefig('ener_comp.jpg', bbox_inches='tight', dpi=500)

# %%
files.sort()

# %%
files
# Out:
# ['energy_3x3x3.txt',
#  'energy_4x4x4.txt',
#  'energy_7x7x7.txt',
#  'energy_8x8x8.txt',
#  'energy_9x9x9.txt']
