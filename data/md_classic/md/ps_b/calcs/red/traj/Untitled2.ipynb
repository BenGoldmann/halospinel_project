# %% [markdown]
# # Li-Cl

# %%
import matplotlib.pyplot as plt

dataset = ['rdf_data_licl.txt', 'rdf_ideal_licl.txt']

for ds in dataset:
    data = open(ds, 'r')
    lines = data.readlines()

    x = []
    y = []

    for line in lines[2:]:
        step = line.split()
        x.append(float(step[0]))
        y.append(float(step[1]))
    
    if max(y) > 6:
        y = [i/(max(y)/6) for i in y]
    
    plt.plot(x, y)

plt.xlabel('Pair separation distance', size=12)
plt.ylabel('g(r)', size=12)
plt.title('Li-Cl', size = 20)
plt.savefig('rdf_licl.jpg', bbox_inches='tight', dpi=500)

# %% [markdown]
# # Sc-Cl

# %%
import matplotlib.pyplot as plt

dataset = ['rdf_data_sccl_partial.txt']
second = ['rdf_data_sccl.txt']
third = ['ideal_rdf_sccl.txt']


for ds in third:
    data = open(ds, 'r')
    lines = data.readlines()

    x = []
    y = []

    for line in lines[2:]:
        step = line.split()
        x.append(float(step[0]))
        y.append(float(step[1]))
    
    plt.plot(x, y, color='wheat')  
    plt.fill_between(x, y, color='oldlace')

for ds in dataset:
    data = open(ds, 'r')
    lines = data.readlines()

    x = []
    y = []
    z = []
    zz = []

    for line in lines[2:]:
        step = line.split()
        if len(step) == 2:
            x.append(float(step[0]))
            y.append(float(step[1]))
        else:
            x.append(float(step[0]))
            y.append(float(step[4]))
            z.append(float(step[5]))
            zz.append(float(step[6]))
            
    plt.plot(x, y, color='tab:blue')
    
    plt.plot(x, z, color='tab:red')
    
    plt.plot(x, zz, color='tab:green')

for ds in second:
    data = open(ds, 'r')
    lines = data.readlines()

    x = []
    y = []

    for line in lines[2:]:
        step = line.split()
        x.append(float(step[0]))
        y.append(float(step[1]))
    
    plt.plot(x, y, color='black')        

plt.ylim(0, 15)    
    
plt.legend(['DFT', 'Sc-Sc', 'Sc-Cl', 'Cl-Cl', 'Total'])
plt.xlabel('Pair separation distance ($\mathrm{\AA}$)', size=12)
plt.ylabel('g(r)', size=12)
plt.savefig('rdf_sccl_partial.jpg', bbox_inches='tight', dpi=500)

# %%
import matplotlib.pyplot as plt

dataset = ['rdf_ideal_sccl_partial.txt']
second = ['rdf_ideal_sccl.txt']

for ds in dataset:
    data = open(ds, 'r')
    lines = data.readlines()

    x = []
    y = []
    z = []
    zz = []

    for line in lines[2:]:
        step = line.split()
        if len(step) == 2:
            x.append(float(step[0]))
            y.append(float(step[1]))
        else:
            x.append(float(step[0]))
            y.append(float(step[4]))
            z.append(float(step[5]))
            zz.append(float(step[6]))
            
    plt.plot(x, y, color='tab:blue')
    
    plt.plot(x, z, color='tab:orange')
    
    plt.plot(x, zz, color='tab:green')

for ds in second:
    data = open(ds, 'r')
    lines = data.readlines()

    x = []
    y = []

    for line in lines[2:]:
        step = line.split()
        x.append(float(step[0]))
        y.append(float(step[1]))
    
    plt.plot(x, y, color='black')        

plt.ylim(0, 15)    
    
plt.legend(['Sc-Sc', 'Sc-Cl', 'Cl-Cl', 'Sum'])
plt.xlabel('Pair separation distance ($\mathrm{\AA}$)', size=12)
plt.ylabel('g(r)', size=12)
plt.title('Sc-Cl', size = 20)
plt.savefig('rdf_sccl_partial_ideal.jpg', bbox_inches='tight', dpi=500)

# %% [markdown]
# # Sc-Cl Partial

# %% [markdown]
# # Li-Sc

# %%
import matplotlib.pyplot as plt

dataset = ['rdf_data_lisc.txt', 'rdf_ideal_lisc.txt']

for ds in dataset:
    data = open(ds, 'r')
    lines = data.readlines()

    x = []
    y = []

    for line in lines[2:]:
        step = line.split()
        x.append(float(step[0]))
        y.append(float(step[1]))
    
    if max(y) > 6:
        y = [i/(max(y)/6) for i in y]
    
    plt.plot(x, y)
    
plt.xlabel('Pair separation distance', size=12)
plt.ylabel('g(r)', size=12)
plt.title('Li-Sc', size = 20)
plt.savefig('rdf_lisc.jpg', bbox_inches='tight', dpi=500)

# %% [markdown]
# # Li-Li

# %%
import matplotlib.pyplot as plt

dataset = ['rdf_data_li.txt', 'rdf_ideal_li.txt']

for ds in dataset:
    data = open(ds, 'r')
    lines = data.readlines()

    x = []
    y = []

    for line in lines[2:]:
        step = line.split()
        x.append(float(step[0]))
        y.append(float(step[1]))
    
    if max(y) > 6:
        y = [i/(max(y)/6) for i in y]
    
    plt.plot(x, y)
    
plt.xlabel('Pair separation distance', size=12)
plt.ylabel('g(r)', size=12)
plt.title('Li-Li', size = 20)
plt.savefig('rdf_li.jpg', bbox_inches='tight', dpi=500)

# %% [markdown]
# # Sc-Sc

# %%
import matplotlib.pyplot as plt

dataset = ['rdf_data_sc.txt', 'rdf_ideal_sc.txt']

for ds in dataset:
    data = open(ds, 'r')
    lines = data.readlines()

    x = []
    y = []

    for line in lines[2:]:
        step = line.split()
        x.append(float(step[0]))
        y.append(float(step[1]))
    
    if max(y) > 6:
        y = [i/(max(y)/6) for i in y]
    
    plt.plot(x, y)
    
plt.xlabel('Pair separation distance', size=12)
plt.ylabel('g(r)', size=12)
plt.title('Sc-Sc', size = 20)
plt.savefig('rdf_sc.jpg', bbox_inches='tight', dpi=500)

# %% [markdown]
# # Cl-Cl

# %%
import matplotlib.pyplot as plt

dataset = ['rdf_data_cl.txt', 'rdf_ideal_cl.txt']

for ds in dataset:
    data = open(ds, 'r')
    lines = data.readlines()

    x = []
    y = []

    for line in lines[2:]:
        step = line.split()
        x.append(float(step[0]))
        y.append(float(step[1]))
    
    if max(y) > 6:
        y = [i/(max(y)/6) for i in y]
    
    plt.plot(x, y)
    
plt.xlabel('Pair separation distance', size=12)
plt.ylabel('g(r)', size=12)
plt.title('Cl-Cl', size = 20)
plt.savefig('rdf_cl.jpg', bbox_inches='tight', dpi=500)
