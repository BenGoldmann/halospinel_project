# %%
import matplotlib.pyplot as plt
import numpy as np
import glob

d = 3

files = glob.glob('a300*')
diffusion_dict = {}
conductivity_dict = {}

def plot_msd(msd_file):  

    # Import MSD files as lists:
    step, msd = np.loadtxt(msd_file, skiprows=2, unpack=True)
    
    # Convert to nanoseconds:
    steps = step / 1000000
    
    # Remove initial jump:
    msd = msd - msd[10000]

    # Plot MSD:   
    plt.plot(steps[10000:], msd[10000:])  

for f in files:
    plot_msd(f)
    
plt.xlabel('time, ns', size = 12)
plt.ylabel('MSD, A^2', size = 12)
plt.legend(['stationary', 'mobile'])
plt.title('300K')

print(diffusion_dict)
print(conductivity_dict)

def make_square_axes(ax):
    """Make an axes square in screen units.

    Should be called after plotting.
    """
    ax.set_aspect(1 / ax.get_data_ratio())

make_square_axes(plt.gca())

plt.savefig('msd_comp_300_.jpg', bbox_inches='tight', dpi=500)
# Out:
# {}
# {}

# %%
import matplotlib.pyplot as plt
import numpy as np
import glob

d = 3

files = glob.glob('600*.txt')
diffusion_dict = {}
conductivity_dict = {}

def plot_msd(msd_file):  

    # Import MSD files as lists:
    step, msd = np.loadtxt(msd_file, skiprows=2, unpack=True)
    
    # Convert to nanoseconds:
    steps = step / 1000000
    
    # Remove initial jump:
    msd = msd - msd[1]

    # Plot MSD:   
    plt.plot(steps[1:], msd[1:])  

for f in files:
    plot_msd(f)
    
plt.xlabel('time, ns', size = 12)
plt.ylabel('MSD, A^2', size = 12)

print(diffusion_dict)
print(conductivity_dict)

def make_square_axes(ax):
    """Make an axes square in screen units.

    Should be called after plotting.
    """
    ax.set_aspect(1 / ax.get_data_ratio())

make_square_axes(plt.gca())

plt.savefig('msd_comp_600.jpg', bbox_inches='tight', dpi=500)
# Out:
# {}
# {}

# %%
files
# Out:
# ['a300_ovito_stationary.txt', 'a300_ovito_mobile.txt']

# %%
e[:3]
# Out:
# '300'
