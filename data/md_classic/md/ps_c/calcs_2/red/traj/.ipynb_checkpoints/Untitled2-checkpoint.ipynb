# %% [markdown]
# # Li-Cl

# %%
import matplotlib.pyplot as plt

dataset = ['rdf_data_licl.txt', 'rdf_ideal_licl.txt']

for ds in dataset:
    data = open(ds, 'r')
    lines = data.readlines()

    x = []
    y = []

    for line in lines[2:]:
        step = line.split()
        x.append(float(step[0]))
        y.append(float(step[1]))
    
    if max(y) > 3:
        y = [i/(max(y)/3) for i in y]
    
    plt.plot(x, y)

# %% [markdown]
# # Sc-Cl

# %%
import matplotlib.pyplot as plt

dataset = ['rdf_data_sccl.txt', 'rdf_ideal_sccl.txt']

for ds in dataset:
    data = open(ds, 'r')
    lines = data.readlines()

    x = []
    y = []

    for line in lines[2:]:
        step = line.split()
        x.append(float(step[0]))
        y.append(float(step[1]))
    
    if max(y) > 3:
        y = [i/(max(y)/3) for i in y]
    
    plt.plot(x, y)

# %% [markdown]
# # Li-Sc

# %%
import matplotlib.pyplot as plt

dataset = ['rdf_data_lisc.txt', 'rdf_ideal_lisc.txt']

for ds in dataset:
    data = open(ds, 'r')
    lines = data.readlines()

    x = []
    y = []

    for line in lines[2:]:
        step = line.split()
        x.append(float(step[0]))
        y.append(float(step[1]))
    
    if max(y) > 3:
        y = [i/(max(y)/3) for i in y]
    
    plt.plot(x, y)

# %% [markdown]
# # Li-Li

# %%
import matplotlib.pyplot as plt

dataset = ['rdf_data_li.txt', 'rdf_ideal_li.txt']

for ds in dataset:
    data = open(ds, 'r')
    lines = data.readlines()

    x = []
    y = []

    for line in lines[2:]:
        step = line.split()
        x.append(float(step[0]))
        y.append(float(step[1]))
    
    if max(y) > 3:
        y = [i/(max(y)/3) for i in y]
    
    plt.plot(x, y)

# %% [markdown]
# # Sc-Sc

# %%
import matplotlib.pyplot as plt

dataset = ['rdf_data_sc.txt', 'rdf_ideal_sc.txt']

for ds in dataset:
    data = open(ds, 'r')
    lines = data.readlines()

    x = []
    y = []

    for line in lines[2:]:
        step = line.split()
        x.append(float(step[0]))
        y.append(float(step[1]))
    
    if max(y) > 3:
        y = [i/(max(y)/3) for i in y]
    
    plt.plot(x, y)

# %% [markdown]
# # Cl-Cl

# %%
import matplotlib.pyplot as plt

dataset = ['rdf_data_cl.txt', 'rdf_ideal_cl.txt']

for ds in dataset:
    data = open(ds, 'r')
    lines = data.readlines()

    x = []
    y = []

    for line in lines[2:]:
        step = line.split()
        x.append(float(step[0]))
        y.append(float(step[1]))
    
    if max(y) > 3:
        y = [i/(max(y)/3) for i in y]
    
    plt.plot(x, y)
