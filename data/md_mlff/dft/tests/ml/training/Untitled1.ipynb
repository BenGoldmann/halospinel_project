# %%
file = open('rmse', 'r')

lines = file.readlines()

s01 = []
s02 = []
s03 = []
s04 = []
s05 = []
s06 = []
s07 = []
s08 = []

for l in lines:
    if 's01' in l:
        data = s01
    if 's02' in l:
        data = s02
    if 's03' in l:
        data = s03
    if 's04' in l:
        data = s04
    if 's05' in l:
        data = s05
    if 's06' in l:
        data = s06
    if 's07' in l:
        data = s07
    if 's08' in l:
        data = s08
    elif 's0' not in l:
        split = l.split()
        data.append(float(split[2]))

# %%
import matplotlib.pyplot as plt
import numpy as np

s01_steps = np.arange(0, len(s01))
s02_steps = np.arange(max(s01_steps)+1, max(s01_steps)+1+len(s02))
s03_steps = np.arange(max(s02_steps)+1, max(s02_steps)+1+len(s03))
s04_steps = np.arange(max(s03_steps)+1, max(s03_steps)+1+len(s04))
s05_steps = np.arange(max(s04_steps)+1, max(s04_steps)+1+len(s05))
s06_steps = np.arange(max(s05_steps)+1, max(s05_steps)+1+len(s06))
s07_steps = np.arange(max(s06_steps)+1, max(s06_steps)+1+len(s07))
s08_steps = np.arange(max(s07_steps)+1, max(s07_steps)+1+len(s08))

plt.plot(s01_steps[1:], s01[1:])
plt.plot(s02_steps[1:], s02[1:])
plt.plot(s03_steps[1:], s03[1:])
plt.plot(s04_steps[1:], s04[1:])
plt.plot(s05_steps[1:], s05[1:])
plt.plot(s06_steps[1:], s06[1:])
plt.plot(s07_steps[1:], s07[1:])
plt.plot(s08_steps[1:], s08[1:])

plt.savefig('RMSE.jpg', dppi=500)
# Out:
# <ipython-input-60-18a52cff8d0a>:22: MatplotlibDeprecationWarning: savefig() got unexpected keyword argument "dppi" which is no longer supported as of 3.3 and will become an error two minor releases later
#   plt.savefig('RMSE.jpg', dppi=500)

# %%
file = open('rmse', 'r')

lines = file.readlines()

s01_s = []
s02_s = []
s03_s = []
s04_s = []
s05_s = []
s06_s = []
s07_s = []
s08_s = []

for l in lines:
    if 's01' in l:
        data = s01_s
    if 's02' in l:
        data = s02_s
    if 's03' in l:
        data = s03_s
    if 's04' in l:
        data = s04_s
    if 's05' in l:
        data = s05_s
    if 's06' in l:
        data = s06_s
    if 's07' in l:
        data = s07_s
    if 's08' in l:
        data = s08_s
    elif 's0' not in l:
        split = l.split()
        data.append(float(split[1]))

# %%
import matplotlib.pyplot as plt
import numpy as np

steps = np.arange(0,5000)

plt.scatter(s01_s[1:], s01[1:])
plt.scatter(s02_s[1:], s02[1:])
plt.scatter(s03_s[1:], s03[1:])
plt.scatter(s04_s[1:], s04[1:])
plt.scatter(s05_s[1:], s05[1:])
plt.scatter(s06_s[1:], s06[1:])
plt.scatter(s07_s[1:], s07[1:])
plt.scatter(s08_s[1:], s08[1:])

legend_list = ['STG1', 'STG2', 'STG3', 'STG4', 'STG5', 'STG6', 'STG7', 'STG8']

plt.legend(legend_list)

#plt.xlim(3900, 5100)

plt.savefig('RMSE.jpg', dppi=500)
# Out:
# <ipython-input-65-dcb13640601b>:21: MatplotlibDeprecationWarning: savefig() got unexpected keyword argument "dppi" which is no longer supported as of 3.3 and will become an error two minor releases later
#   plt.savefig('RMSE.jpg', dppi=500)

# %%
s01_ss = []
s02_ss = []
s03_ss = []
s04_ss = []
s05_ss = []
s06_ss = []
s07_ss = []
s08_ss = []

for i in s01_s:
    s01_ss.append(1)

for i in s02_s:
    s02_ss.append(2)
    
for i in s03_s:
    s03_ss.append(3)
    
for i in s04_s:
    s04_ss.append(4)
    
for i in s05_s:
    s05_ss.append(5)
    
for i in s06_s:
    s06_ss.append(6)

for i in s07_s:
    s07_ss.append(7)

for i in s08_s:
    s08_ss.append(8)
    
plt.scatter(s01_s, s01_ss)
plt.scatter(s02_s, s02_ss)
plt.scatter(s03_s, s03_ss)
plt.scatter(s04_s, s04_ss)
plt.scatter(s05_s, s05_ss)
plt.scatter(s06_s, s06_ss)
plt.scatter(s07_s, s07_ss)
plt.scatter(s08_s, s08_ss)

plt.xlabel('Step number')
plt.ylabel('Stage number')
plt.title('Plot showing at what step action (3) or (4) took place for each stage.')

plt.savefig('learning.jpg', dppi=500)
# Out:
# <ipython-input-71-084143e51abd>:47: MatplotlibDeprecationWarning: savefig() got unexpected keyword argument "dppi" which is no longer supported as of 3.3 and will become an error two minor releases later
#   plt.savefig('learning.jpg', dppi=500)
