# %%
from pymatgen.io.vasp.outputs import Xdatcar
from pymatgen.io.vasp.outputs import Oszicar
import numpy as np
import matplotlib.pyplot as plt

# %%
T = 900

xdatcar = Xdatcar(f'XDATCAR_{T}k')

structures = xdatcar.structures

# %%
oszicar = Oszicar(f'OSZICAR_{T}k')

ionic_steps = oszicar.ionic_steps

# %%
a_param = []
b_param = []
c_param = []
alpha_param = []
beta_param = []
gamma_param = []

for s in structures:
    a_param.append(s.lattice.a)
    b_param.append(s.lattice.b)
    c_param.append(s.lattice.c)
    alpha_param.append(s.lattice.alpha)
    beta_param.append(s.lattice.beta)
    gamma_param.append(s.lattice.gamma)

energies = []    
    
for i in ionic_steps:
    energies.append(i['E0'])

# %%
step = np.arange(0, len(a_param))
time = step*2

# %%
plt.plot(time, energies)

# %%
print(f'a: {np.mean(a_param[500:1000])}')
print(f'b: {np.mean(b_param[500:1000])}')
print(f'c: {np.mean(c_param[500:1000])}')
print(f'alpha: {np.mean(alpha_param[500:1000])}')
print(f'beta: {np.mean(beta_param[500:1000])}')
print(f'gamma: {np.mean(gamma_param[500:1000])}')
# Out:
# a: 21.88710789190013
# b: 21.688691548045206
# c: 22.24903140700238
# alpha: 90.53326481668809
# beta: 89.83589506186863
# gamma: 89.93253632908008

# %%
plt.plot(time, a_param)
plt.plot(time, b_param)
plt.plot(time, c_param)

# %%
plt.plot(time, alpha_param)
plt.plot(time, beta_param)
plt.plot(time, gamma_param)

# %%
ionic_steps[0]['E0']
# Out:
# -1875.7942

# %%
y
