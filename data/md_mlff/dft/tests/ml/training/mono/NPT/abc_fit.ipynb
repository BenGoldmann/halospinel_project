# %%
a = [19.295904555547587, 19.457761068936907, 20.217484091461053, 20.136527804886835]
b = [22.42102012826343, 22.622780362049333, 23.20572964901875, 23.302439388024496]
c = [19.560621276331105, 19.84521687678244, 20.208563977260017, 20.548278404266572]
t = 600, 700, 800, 900

# %%
import matplotlib.pyplot as plt

plt.plot(t, a)
plt.plot(t, b)
plt.plot(t, c)

# %%
import numpy as np

a_slope, a_intercept = np.polyfit(t, a, 1)
b_slope, b_intercept = np.polyfit(t, b, 1)
c_slope, c_intercept = np.polyfit(t, c, 1)

plt.plot([600, 900], [600*a_slope+a_intercept, 900*a_slope+a_intercept])
plt.plot([600, 900], [600*b_slope+b_intercept, 900*b_slope+b_intercept])
plt.plot([600, 900], [600*c_slope+c_intercept, 900*c_slope+c_intercept])

ave_slope = np.mean([a_slope, b_slope, c_slope])
ave_intercept = np.mean([a_intercept, b_intercept, c_intercept])

#plt.plot([600, 900], [600*ave_slope+ave_intercept, 900*ave_slope+ave_intercept], color= 'black')

# %%
T = 900

print(f'a: {T*a_slope+a_intercept}')
print(f'b: {T*b_slope+b_intercept}')
print(f'c: {T*c_slope+c_intercept}')
# Out:
# a: 20.269158295789385
# b: 23.372073441776898
# c: 20.539617906302638

# %%
import numpy as np

ave_600 = np.mean([((a[0]-18.68504)/18.68504)*100, ((b[0]-21.85894)/21.85894)*100, ((c[0]-18.85199)/18.85199)*100])
ave_700 = np.mean([((a[1]-18.68504)/18.68504)*100, ((b[1]-21.85894)/21.85894)*100, ((c[1]-18.85199)/18.851992)*100])
ave_800 = np.mean([((a[2]-18.68504)/18.68504)*100, ((b[2]-21.85894)/21.85894)*100, ((c[2]-18.85199)/18.85199)*100])
ave_900 = np.mean([((a[3]-18.68504)/18.68504)*100, ((b[3]-21.85894)/21.85894)*100, ((c[3]-18.85199)/18.85199)*100])

ave = [ave_600, ave_700, ave_800, ave_900]

plt.plot(t, ave)

# %%
print(a_slope)
print(b_slope)
print(c_slope)
# Out:
# 0.00328159277054189
# 0.0032272070662526346
# 0.0033263184842839853

# %%
ave
# Out:
# [3.1998626944620057, 4.299488374010129, 7.186214904129084, 7.789937191195169]
