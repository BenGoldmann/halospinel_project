# %%
import matplotlib.pyplot as plt

steps = [0, 10, 20, 30, 40, 50]
ML_CX_00 = [0, 3828, 5158, 6335, 7504, 8533]
ML_CX_01 = [0, 3228, 4534, 5707, 6812, 7784]
ML_CX_02 = [0, 2606, 3978, 5231, 6344, 7358]
ML_CX_03 = [0, 2293, 3636, 4904, 6093, 7130]

plt.plot(steps, ML_CX_00, marker='o')
plt.plot(steps, ML_CX_01, marker='o')
plt.plot(steps, ML_CX_02, marker='o')
plt.plot(steps, ML_CX_03, marker='o')
plt.xlabel('Training time, ps')
plt.ylabel('Local configurations in DS')
plt.legend(['ML_CX = 0.0', 'ML_CX = 0.1', 'ML_CX = 0.2', 'ML_CX = 0.3'])
plt.savefig('config_time_all.jpg', bbox_inches='tight', dpi=500)

# %%
steps = [0, 10, 20, 30, 40, 50]
ML_CX_00 = [0, 3828, 5158, 6335, 7504, 8533]
plt.plot(steps, ML_CX_00, marker='o')
plt.xlabel('Training time, ps')
plt.ylabel('Local configurations in DS')
plt.savefig('config_time.jpg', bbox_inches='tight', dpi=500)

# %%
steps = [10, 20, 30, 40, 50]
rms_energy = [0.00123, 0.00116, 0.00112, 0.00113, 0.00119]
plt.plot(steps, rms_energy, marker='o')
plt.xlabel('Training time, ps')
plt.ylabel('RMS Energy (eV/atom)')
plt.savefig('energy_time.jpg', bbox_inches='tight', dpi=500)

# %%
steps = [10, 20, 30, 40, 50]
rms_energy = [0.0259, 0.0256, 0.0257, 0.0257, 0.0254]
plt.plot(steps, rms_energy, marker='o')
plt.xlabel('Training time, ps')
plt.ylabel('RMS Force on Li (eV/AA)')
plt.savefig('force_time.jpg', bbox_inches='tight', dpi=500)
